# %%
# %run generate.py
# Out:
# ...
#   ANTARCTICA DIGITAL TWIN SIMULATOR V2 — BATCH GENERATION
#   Simulating 7,300 days (20.0 years) for 2 stations
#   Start Date: 2003-01-01
# ...
#
# [Simulator] Initializing Digital Twin for Maitri (MAITRI)...
#   -> Simulating Maitri: Day 7,300/7,300 (2022-12-26)
#   -> Completed 7,300 days for Maitri.
#
# [Simulator] Initializing Digital Twin for Bharati (BHARATI)...
#   -> Simulating Bharati: Day 7,300/7,300 (2022-12-26)
#   -> Completed 7,300 days for Bharati.
#
# [Simulator] Compiling output DataFrames...
# [Simulator] Generated 14,600 station records and 408,800 inventory records in 55.18 seconds.
# [Simulator] Saving dataset -> station_summary.csv & C:\Users\krish\OneDrive\Desktop\SIH\data\station_summary.csv
# [Simulator] Saving dataset -> inventory_items.csv & C:\Users\krish\OneDrive\Desktop\SIH\data\inventory_items.csv
# ...
#   SIMULATION COMPLETE — All datasets successfully written.
# ...
